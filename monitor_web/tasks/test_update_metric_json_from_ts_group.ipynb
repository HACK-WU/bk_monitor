# %%
import sys

sys.path.append('D:\PythonProjects\\bk-monitor\\venv2\share\scripts')
import hello

# %%
metric_json = {
    "plugin_id": "hwm_test3",
    "plugin_type": "Exporter",
    "config_version": 1,
    "info_version": 3,
    "enable_field_blacklist": "false",
    "metric_json": [
        {
            "table_name": "group_default",
            "table_desc": "默认分组",
            "fields": [
                {
                    "description": "m1",
                    "type": "double",
                    "monitor_type": "metric",
                    "unit": "none",
                    "name": "m1",
                    "is_diff_metric": "false",
                    "is_active": "true",
                    "source_name": "",
                    "dimensions": [],
                    "is_manual": "false",
                    "tag_list": [
                        {
                            "field_name": "w2",
                            "unit": "none",
                            "type": "string",
                            "description": "w2"
                        },
                    ],
                    "isDisabled": "false",
                    "order": 0
                },
                {
                    "description": "m2",
                    "type": "double",
                    "monitor_type": "metric",
                    "unit": "none",
                    "name": "m2",
                    "is_diff_metric": "false",
                    "is_active": "true",
                    "source_name": "",
                    "dimensions": [],
                    "is_manual": "false",
                    "tag_list": [{
                        "field_name": "w2",
                        "unit": "none",
                        "type": "string",
                        "description": "w2"
                    }, ],
                    "isDisabled": "false",
                    "order": 0
                },
                {
                    "description": "w2",
                    "type": "string",
                    "monitor_type": "dimension",
                    "unit": "none",
                    "name": "w2",
                    "is_diff_metric": "false",
                    "is_active": "true",
                    "source_name": "",
                    "is_manual": "false",
                    "tag_list": [],
                    "isDisabled": "false",
                    "order": 1
                },
                {
                    "description": "w1",
                    "type": "string",
                    "monitor_type": "dimension",
                    "unit": "none",
                    "name": "w1",
                    "is_diff_metric": "false",
                    "is_active": "true",
                    "source_name": "",
                    "is_manual": "false",
                    "tag_list": [],
                    "isDisabled": "false",
                    "order": 1
                },
                {
                    "monitor_type": "dimension",
                    "name": "disk_w1",
                    "description": "disk_w1",
                    "source_name": "",
                    "value": {
                        "linux": "null",
                        "windows": "null",
                        "aix": "null"
                    },
                    "is_active": "true",
                    "is_diff_metric": "false",
                    "order": 3,
                    "type": "string",
                    "unit": "--",
                    "is_manual": "false"
                }
            ],
            "rule_list": []
        },
        {
            "table_name": "disk",
            "table_desc": "disk",
            "rule_list": [
                "disk"
            ],
            "fields": [
                {
                    "monitor_type": "metric",
                    "name": "disk_m2",
                    "description": "disk_m2",
                    "source_name": "",
                    "value": {
                        "linux": "null",
                        "windows": "null",
                        "aix": "null"
                    },
                    "is_active": "true",
                    "is_diff_metric": "false",
                    "order": 1,
                    "dimensions": [],
                    "tag_list": [],
                    "type": "double",
                    "unit": "none",
                    "is_manual": "false"
                },
                {
                    "monitor_type": "metric",
                    "name": "disk_m1",
                    "description": "disk_m1",
                    "source_name": "",
                    "value": {
                        "linux": "null",
                        "windows": "null",
                        "aix": "null"
                    },
                    "is_active": "true",
                    "is_diff_metric": "false",
                    "order": 1,
                    "dimensions": [],
                    "tag_list": [],
                    "type": "double",
                    "unit": "none",
                    "is_manual": "false"
                }
            ]
        },
        {
            "table_name": "cpu",
            "table_desc": "cpu",
            "rule_list": [
                "cpu"
            ],
            "fields": [
                {
                    "monitor_type": "metric",
                    "name": "cpu_m2",
                    "description": "cpu_m2",
                    "source_name": "",
                    "value": {
                        "linux": "null",
                        "windows": "null",
                        "aix": "null"
                    },
                    "is_active": "true",
                    "is_diff_metric": "false",
                    "order": 1,
                    "dimensions": [],
                    "tag_list": [],
                    "type": "double",
                    "unit": "none",
                    "is_manual": "false"
                },
                {
                    "monitor_type": "metric",
                    "name": "cpu_m1",
                    "description": "cpu_m1",
                    "source_name": "",
                    "value": {
                        "linux": "null",
                        "windows": "null",
                        "aix": "null"
                    },
                    "is_active": "true",
                    "is_diff_metric": "false",
                    "order": 1,
                    "dimensions": [],
                    "tag_list": [],
                    "type": "double",
                    "unit": "none",
                    "is_manual": "false"
                },
                {
                    "description": "cpu_w2",
                    "type": "string",
                    "monitor_type": "dimension",
                    "unit": "none",
                    "name": "cpu_w2",
                    "is_diff_metric": "false",
                    "is_active": "true",
                    "source_name": "",
                    "is_manual": "false",
                    "tag_list": [],
                    "isDisabled": "false",
                    "order": 0
                },
            ]
        }
    ],
    "need_upgrade": "true",
    "bk_biz_id": 2
}

metric_info_list = [
    # {                             #需要进行删除的维度
    #     "field_name": "m1",
    #     "tag_list": [
    #         {
    #             "field_name": "w2",
    #             "unit": "none",
    #             "type": "string",
    #             "description": "w2"
    #         },
    #         {
    #             "field_name": "w1",
    #             "unit": "none",
    #             "type": "string",
    #             "description": "w1"
    #         },
    #         {
    #             "field_name": "disk_w1",
    #             "unit": "none",
    #             "type": "string",
    #             "description": "disk_w1"
    #         }
    #     ],
    #     "label": "null",
    #     "is_active": "true"
    # },
    {
        "field_name": "m2",
        "tag_list": [
            {
                "field_name": "w1",
                "unit": "none",
                "type": "string",
                "description": "w1"
            },
            {
                "field_name": "disk_w1",
                "unit": "none",
                "type": "string",
                "description": "disk_w1"
            }
        ],
        "label": "null",
        "is_active": "true"
    },
    {
        "field_name": "disk_m2",
        "tag_list": [

        ],
        "label": "null",
        "is_active": "true"
    },
    # {                             # 删除的指标
    #     "field_name": "disk_m1",
    #     "tag_list": [
    # 
    #     ],
    #     "label": "null",
    #     "is_active": "true"
    # },
    {
        "field_name": "cpu_m2",
        "tag_list": [
            {
                "field_name": "cpu_w4",
                "unit": "none",
                "type": "string",
                "description": "cpu_w4"
            }
        ],
        "label": "null",
        "is_active": "true"
    },
    # {                                     //删除的指标
    #     "field_name": "cpu_m1",
    #     "tag_list": [
    #         {
    #             "field_name": "cpu_w2",
    #             "unit": "none",
    #             "type": "string",
    #             "description": "cpu_w2"
    #         }
    #     ],
    #     "label": "null",
    #     "is_active": "true"
    # }
]

add_metric_info_list = [
    {
        "field_name": "add_m1",  # 新增的指标
        "tag_list": [
            {
                "field_name": "add_w5",  # 新增的维度
                "unit": "none",
                "type": "string",
                "description": "新增的维度"
            },
            # {                          # 删除的维度
            #     "field_name": "w2",
            #     "unit": "none",
            #     "type": "string",
            #     "description": "w2"
            # },
            {
                "field_name": "w1",
                "unit": "none",
                "type": "string",
                "description": "w1"
            },
            {
                "field_name": "disk_w1",
                "unit": "none",
                "type": "string",
                "description": "disk_w1"
            }
        ],
        "label": "null",
        "is_active": "true"
    },
    {
        "field_name": "add_cpu_m1",  # 新增的指标
        "tag_list": [
            {
                "field_name": "add_cpu_w1",  # 新增的维度
                "unit": "none",
                "type": "string",
                "description": "新增的cpu维度"
            },
            # {
            #     "field_name": "cpu_w2",   # 删除的维度
            #     "unit": "none",
            #     "type": "string",
            #     "description": "cpu_w2"
            # }
        ],
        "label": "null",
        "is_active": "true"
    }
]

metric_info_list += add_metric_info_list
# 单指标单表中，一个group中只有一个指标
group_list = [
    {
        'time_series_group_id': 1,
        'time_series_group_name': 'bkunifylogbeat common metrics',
        'bk_data_id': 1100006,
        'bk_biz_id': 0,
        'table_id': 'bkunifylogbeat_common.base',
        'label': 'service_process',
        'is_enable': True,
        'creator': 'system',
        'create_time': '2021-12-07 03:29:51',
        'last_modify_user': 'system',
        'last_modify_time': '2021-12-07 03:29:51',
        "metric_info_list": [metric]
    } for metric in metric_info_list
]
metric_json = metric_json["metric_json"]


def dump(dic):
    return json.dumps(dic, indent=4, ensure_ascii=False)

# %%
from mock import MagicMock, patch
from monitor_web.commons.data_access import PluginDataAccessor
from monitor_web.models.plugin import CollectorPluginConfig, CollectorPluginInfo, PluginVersionHistory, \
    CollectorPluginMeta
import json


def test_format_time_series_metric_info_data():
    current_version = MagicMock()
    current_version.info.metric_json = metric_json
    current_version.info.save.return_value = True
    instance = PluginDataAccessor(current_version, "admin")
    instance.merge_dimensions = MagicMock(return_value=[])
    result = instance.format_time_series_metric_info_data(metric_json, False)
    return result


result = test_format_time_series_metric_info_data()
print(json.dumps(result, indent=4, ensure_ascii=False))

# %%
import copy

meta = CollectorPluginMeta()
meta.current_version = MagicMock()
meta.current_version.info = CollectorPluginInfo()
meta.reserved_dimension_list = MagicMock(return_value=[])
meta.current_version.info.metric_json = copy.deepcopy(metric_json)


def test_filter_metric_by_table_rule():
    # 通过 table rule 对指标进行自动匹配分组
    match_result, not_match_result, map_of_metric_and_tag = meta.filter_metric_by_table_rule(group_list)
    print("match_result: ", dump(match_result))
    print("not_match_result: ", dump(not_match_result))
    print("map_of_metric_and_tag: ", dump(map_of_metric_and_tag))


test_filter_metric_by_table_rule()

# %%
meta.reserved_dimension_list = []
meta.current_version.info.metric_json = copy.deepcopy(metric_json)


def test_update_metric_json_from_ts_group():
    result = meta.update_metric_json_from_ts_group(group_list)
    print("result: ", dump(meta.current_version.info.metric_json))


test_update_metric_json_from_ts_group()
# Out:
# result:  [
#     {
#         "table_name":"group_default",
#         "table_desc":"默认分组",
#         "fields":[
#             {
#                 "description":"m2",
#                 "type":"double",
#                 "monitor_type":"metric",
#                 "unit":"none",
#                 "name":"m2",
#                 "is_diff_metric":"false",
#                 "is_active":"true",
#                 "source_name":"",
#                 "dimensions":[
#
#                 ],
#                 "is_manual":"false",
#                 "tag_list":[
#                     {
#                         "field_name":"w1",
#                         "unit":"none",
#                         "type":"string",
#                         "description":"w1"
#                     },
#                     {
#                         "field_name":"disk_w1",
#                         "unit":"none",
#                         "type":"string",
#                         "description":"disk_w1"
# ...
